# %%
import numpy as np
import matplotlib.pyplot as plt; plt.rcdefaults()
import pandas as pd

import warnings
warnings.filterwarnings("ignore")

# fix_yahoo_finance is used to fetch data 
import yfinance as yf
yf.pdr_override()

# %%
# input
symbol = 'TSLA'
start = '2000-01-15'
end = '2024-01-18'

# Read data 
dataset = yf.download(symbol,start,end)

# View Data
dataset.head()

# %%
dataset.tail()

# %%
plt.figure(figsize=(16,8))
plt.plot(dataset['Adj Close'])
plt.title('Closing Price Chart')
plt.xlabel('Date')
plt.ylabel('Price')
plt.grid(True)
plt.show()

# %%
monthly = dataset.asfreq('BM')
monthly['Returns'] = dataset['Adj Close'].pct_change().dropna()
monthly.head()

# %%
monthly['Month_Name'] = monthly.index.strftime("%b")
monthly['Month_Name_Year'] = monthly.index.strftime("%b-%Y")

# %%
import calendar
import datetime

monthly = monthly.reset_index()
monthly['Month'] = monthly["Date"].dt.month

# %%
monthly.head()

# %%
monthly.head()
# Out:
#         Date      Open      High       Low     Close  Adj Close       Volume  \
# 0 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500.0
# 1 2010-07-30  1.346667  1.362667  1.303333  1.329333   1.329333    6403500.0
# 2 2010-08-31  1.310667  1.319333  1.288667  1.298667   1.298667    3016500.0
# 3 2010-09-30  1.466667  1.476667  1.346000  1.360667   1.360667   32937000.0
# 4 2010-10-29  1.409333  1.456667  1.403333  1.456000   1.456000    4209000.0
#
#     Returns Month_Name Month_Name_Year  Month
# 0 -0.002511        Jun        Jun-2010      6
# 1 -0.020148        Jul        Jul-2010      7
# 2 -0.019628        Aug        Aug-2010      8
# 3 -0.071428        Sep        Sep-2010      9
# 4  0.030675        Oct        Oct-2010     10

# %%
monthly.tail()
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 158 2023-08-31  255.979996  261.179993  255.050003  258.079987  258.079987
# 159 2023-09-29  250.000000  254.770004  246.350006  250.220001  250.220001
# 160 2023-10-31  196.119995  202.800003  194.070007  200.839996  200.839996
# 161 2023-11-30  245.139999  245.220001  236.910004  240.080002  240.080002
# 162 2023-12-29  255.100006  255.190002  247.429993  248.479996  248.479996
#
#           Volume   Returns Month_Name Month_Name_Year  Month
# 158  108861700.0  0.004593        Aug        Aug-2023      8
# 159  128346200.0  0.015586        Sep        Sep-2023      9
# 160  118068300.0  0.017633        Oct        Oct-2023     10
# 161  132353200.0 -0.016630        Nov        Nov-2023     11
# 162  100615300.0 -0.018564        Dec        Dec-2023     12

# %%
# input
symbol = 'AMZN'
start = '2000-01-15'
end = '2024-01-18'

# Read data 
dataset = yf.download(symbol,start,end)

# View Data
dataset.head(50)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2000-01-18  3.171875  3.259375  3.150000  3.206250   3.206250  107698000
# 2000-01-19  3.206250  3.375000  3.150000  3.340625   3.340625  164910000
# 2000-01-20  3.346875  3.350000  3.196875  3.237500   3.237500  119560000
# 2000-01-21  3.231250  3.231250  3.000000  3.103125   3.103125  229238000
# 2000-01-24  3.378125  3.668750  3.375000  3.506250   3.506250  583404000
# 2000-01-25  3.500000  3.562500  3.300000  3.462500   3.462500  188682000
# 2000-01-26  3.431250  3.500000  3.237500  3.240625   3.240625  131160000
# 2000-01-27  3.259375  3.387500  3.231250  3.346875   3.346875  135680000
# 2000-01-28  3.250000  3.321875  3.000000  3.084375   3.084375  275558000
# 2000-01-31  3.018750  3.237500  2.921875  3.228125   3.228125  213958000

# Requirement already satisfied: beautifulsoup4>=4.6.0 in c:\users\chris\anaconda3\lib\site-packages (from nb2xls) (4.11.1)
# Requirement already satisfied: xlsxwriter>=1.1.0 in c:\users\chris\anaconda3\lib\site-packages (from nb2xls) (3.0.3)
# Requirement already satisfied: pypng>=0.0.18 in c:\users\chris\anaconda3\lib\site-packages (from nb2xls) (0.20220715.0)
# Requirement already satisfied: numpy in c:\users\chris\anaconda3\lib\site-packages (from nb2xls) (1.21.5)
# Requirement already satisfied: mistune>=0.8 in c:\users\chris\anaconda3\lib\site-packages (from nb2xls) (0.8.4)
# Requirement already satisfied: nbconvert>=5.0.0 in c:\users\chris\anaconda3\lib\site-packages (from nb2xls) (6.4.4)
# Requirement already satisfied: pandas in c:\users\chris\anaconda3\lib\site-packages (from nb2xls) (1.4.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\chris\anaconda3\lib\site-packages (from beautifulsoup4>=4.6.0->nb2xls) (2.3.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\chris\anaconda3\lib\site-packages (from nbconvert>=5.0.0->nb2xls) (0.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\chris\anaconda3\lib\site-packages (from nbconvert>=5.0.0->nb2xls) (0.1.2)
# Requirement already satisfied: bleach in c:\users\chris\anaconda3\lib\site-packages (from nbconvert>=5.0.0->nb2xls) (4.1.0)
# Requirement already satisfied: jupyter-core in c:\users\chris\anaconda3\lib\site-packages (from nbconvert>=5.0.0->nb2xls) (4.11.1)
# Requirement already satisfied: jinja2>=2.4 in c:\users\chris\anaconda3\lib\site-packages (from nbconvert>=5.0.0->nb2xls) (2.11.3)
# Requirement already satisfied: nbformat>=4.4 in c:\users\chris\anaconda3\lib\site-packages (from nbconvert>=5.0.0->nb2xls) (5.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\chris\anaconda3\lib\site-packages (from nbconvert>=5.0.0->nb2xls) (0.5.13)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\chris\anaconda3\lib\site-packages (from nbconvert>=5.0.0->nb2xls) (2.11.2)
# Requirement already satisfied: defusedxml in c:\users\chris\anaconda3\lib\site-packages (from nbconvert>=5.0.0->nb2xls) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\chris\anaconda3\lib\site-packages (from nbconvert>=5.0.0->nb2xls) (1.5.0)
# Requirement already satisfied: testpath in c:\users\chris\anaconda3\lib\site-packages (from nbconvert>=5.0.0->nb2xls) (0.6.0)
# Requirement already satisfied: traitlets>=5.0 in c:\users\chris\anaconda3\lib\site-packages (from nbconvert>=5.0.0->nb2xls) (5.1.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\chris\anaconda3\lib\site-packages (from pandas->nb2xls) (2023.3.post1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\chris\anaconda3\lib\site-packages (from pandas->nb2xls) (2.8.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\chris\anaconda3\lib\site-packages (from jinja2>=2.4->nbconvert>=5.0.0->nb2xls) (2.0.1)
# Requirement already satisfied: jupyter-client>=6.1.5 in c:\users\chris\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=5.0.0->nb2xls) (7.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\chris\anaconda3\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert>=5.0.0->nb2xls) (1.5.5)
# Requirement already satisfied: fastjsonschema in c:\users\chris\anaconda3\lib\site-packages (from nbformat>=4.4->nbconvert>=5.0.0->nb2xls) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\chris\anaconda3\lib\site-packages (from nbformat>=4.4->nbconvert>=5.0.0->nb2xls) (4.16.0)
# Requirement already satisfied: six>=1.5 in c:\users\chris\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas->nb2xls) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\chris\anaconda3\lib\site-packages (from bleach->nbconvert>=5.0.0->nb2xls) (0.5.1)
# Requirement already satisfied: packaging in c:\users\chris\anaconda3\lib\site-packages (from bleach->nbconvert>=5.0.0->nb2xls) (21.3)
# Requirement already satisfied: pywin32>=1.0 in c:\users\chris\anaconda3\lib\site-packages (from jupyter-core->nbconvert>=5.0.0->nb2xls) (302)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\chris\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.4->nbconvert>=5.0.0->nb2xls) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\chris\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat>=4.4->nbconvert>=5.0.0->nb2xls) (0.18.0)
# Requirement already satisfied: tornado>=6.0 in c:\users\chris\anaconda3\lib\site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert>=5.0.0->nb2xls) (6.1)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\chris\anaconda3\lib\site-packages (from jupyter-client>=6.1.5->nbclient<0.6.0,>=0.5.0->nbconvert>=5.0.0->nb2xls) (23.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\chris\anaconda3\lib\site-packages (from packaging->bleach->nbconvert>=5.0.0->nb2xls) (3.0.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
# input
symbol = 'FVRR'
start = '2000-01-15'
end = '2024-01-18'

# Read data 
dataset = yf.download(symbol,start,end)

# View Data
dataset.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2019-06-13  26.000000  41.680000  25.549999  39.900002  39.900002  22046000
# 2019-06-14  41.639999  44.250000  31.490000  31.490000  31.490000  10275800
# 2019-06-17  32.810001  34.880001  31.541000  34.380001  34.380001   3789100
# 2019-06-18  35.259998  35.919998  31.040001  31.150000  31.150000   3274000
# 2019-06-19  31.799999  31.799999  28.250000  28.670000  28.670000   1902000
